# %%
import numpy as np

import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
img=cv2.imread('/content/download (1).jpg')

# %%
grey_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(grey_img,150,200)
from google.colab.patches import cv2_imshow
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1200x673>
