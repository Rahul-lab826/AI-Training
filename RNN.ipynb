# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul-lab826/AI-Training/blob/main/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,models

# %%
mnist=keras.datasets.mnist
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_images,test_images=train_images/255.0,test_images/255.0

# %%
input_shape=(28,28)
inputs=keras.Input(shape=input_shape)
rnn_layer=layers.LSTM(128)(inputs)
outputs=layers.Dense(10,activation='softmax')(rnn_layer)
model=keras.Model(inputs=inputs,outputs=outputs)

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_images,train_labels,validation_split=0.1,epochs=20)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 60s 35ms/step - accuracy: 0.8872 - loss: 0.3518 - val_accuracy: 0.9680 - val_loss: 0.1038
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 80s 33ms/step - accuracy: 0.9659 - loss: 0.1135 - val_accuracy: 0.9668 - val_loss: 0.1019
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 56s 33ms/step - accuracy: 0.9769 - loss: 0.0773 - val_accuracy: 0.9818 - val_loss: 0.0644
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 60s 35ms/step - accuracy: 0.9816 - loss: 0.0599 - val_accuracy: 0.9780 - val_loss: 0.0751
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 59s 35ms/step - accuracy: 0.9855 - loss: 0.0476 - val_accuracy: 0.9838 - val_loss: 0.0547
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 82s 35ms/step - accuracy: 0.9867 - loss: 0.0432 - val_accuracy: 0.9867 - val_loss: 0.0524
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 80s 34ms/step - accuracy: 0.9896 - loss: 0.0331 - val_accuracy: 0.9878 - val_loss: 0.0406
# Epoch 8/20
# ...
